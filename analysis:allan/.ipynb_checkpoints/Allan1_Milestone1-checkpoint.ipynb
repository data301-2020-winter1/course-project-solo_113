# %%
import pandas as pd
df = pd.read_csv('/Users/allannganga/Desktop/School/course-project-solo_113/Data/Data:Raw/fatal-police-shootings-data.csv')
print (df.head())
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# 0  Not fleeing        False   -123.122    47.247                True
# 1  Not fleeing        False   -122.892    45.487                True
# 2  Not fleeing        False    -97.281    37.695                True
# 3  Not fleeing        False   -122.422    37.763                True
# 4  Not fleeing        False   -104.692    40.384                True

# %%
import pandas as pd
df = (pd.read_csv('/Users/allannganga/Desktop/School/course-project-solo_113/Data/Data:Raw/fatal-police-shootings-data.csv')
 .drop(['latitude', 'longitude', 'is_geocoding_exact', 'manner_of_death', 'armed', 'id'], axis=1)
 .rename(columns={'race': 'ethnicity'})
 .reset_index(drop=True))
df
# Out:
#                          name        date   age gender ethnicity  \
# 0                  Tim Elliot  2015-01-02  53.0      M         A
# 1            Lewis Lee Lembke  2015-01-02  47.0      M         W
# 2          John Paul Quintero  2015-01-03  23.0      M         H
# 3             Matthew Hoffman  2015-01-04  32.0      M         W
# 4           Michael Rodriguez  2015-01-04  39.0      M         H
# ...                       ...         ...   ...    ...       ...
# 5711           Gregory Putnik  2020-10-18  32.0      M         W
# 5712  Tutuila Pine Koonwaiyou  2020-10-18  37.0      M       NaN
# 5713                      NaN  2020-10-19  43.0      M       NaN
# 5714           Paul Sulkowski  2020-10-19  46.0      M       NaN
# 5715                      NaN  2020-10-19   NaN      M       NaN
#
#                  city state  signs_of_mental_illness threat_level  \
# 0             Shelton    WA                     True       attack
# 1               Aloha    OR                    False       attack
# 2             Wichita    KS                    False        other
# 3       San Francisco    CA                     True       attack
# 4               Evans    CO                    False       attack
# ...               ...   ...                      ...          ...
# 5711           Fresno    CA                    False       attack
# 5712           Tooele    UT                    False        other
# 5713  South Milwaukee    WI                    False       attack
# 5714            Coram    NY                    False        other
# 5715       Emmitsburg    MD                    False       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 5711         Foot        False
# 5712  Not fleeing        False
# 5713  Not fleeing        False
# 5714          NaN        False
# 5715        Other        False
#
# [5716 rows x 11 columns]

# %%
def load_and_process('/Users/allannganga/Desktop/School/course-project-solo_113/Data/Data:Raw/fatal-police-shootings-data.csv'):

    # Method Chain 1 (Load data and deal with missing data)

   df = (pd.read_csv('/Users/allannganga/Desktop/School/course-project-solo_113/Data/Data:Raw/fatal-police-shootings-data.csv')
 .drop(['latitude', 'longitude', 'is_geocoding_exact', 'manner_of_death', 'armed', 'id'], axis=1)
 .rename(columns={'race': 'ethnicity'})
 .reset_index(drop=True))

    # Method Chain 2 (Create new columns, drop others, and do processing)

    df2 = (
          df
          .assign()
      )

    # Make sure to return the latest dataframe

    return df2
