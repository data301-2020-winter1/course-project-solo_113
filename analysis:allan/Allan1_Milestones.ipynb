# %%
import pandas as pd
df = pd.read_csv('/Users/allannganga/Desktop/School/course-project-solo_113/Data/Data:Raw/fatal-police-shootings-data.csv')
df
# Out:
#         id                     name        date   manner_of_death       armed  \
# 0        3               Tim Elliot  2015-01-02              shot         gun
# 1        4         Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5       John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8          Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9        Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                      ...         ...               ...         ...
# 5711  6245           Gregory Putnik  2020-10-18              shot         gun
# 5712  6247  Tutuila Pine Koonwaiyou  2020-10-18              shot         gun
# 5713  6242                      NaN  2020-10-19              shot         gun
# 5714  6243           Paul Sulkowski  2020-10-19              shot       knife
# 5715  6244                      NaN  2020-10-19              shot         gun
#
#        age gender race             city state  signs_of_mental_illness  \
# 0     53.0      M    A          Shelton    WA                     True
# 1     47.0      M    W            Aloha    OR                    False
# 2     23.0      M    H          Wichita    KS                    False
# 3     32.0      M    W    San Francisco    CA                     True
# 4     39.0      M    H            Evans    CO                    False
# ...    ...    ...  ...              ...   ...                      ...
# 5711  32.0      M    W           Fresno    CA                    False
# 5712  37.0      M  NaN           Tooele    UT                    False
# 5713  43.0      M  NaN  South Milwaukee    WI                    False
# 5714  46.0      M  NaN            Coram    NY                    False
# 5715   NaN      M  NaN       Emmitsburg    MD                    False
#
#      threat_level         flee  body_camera  longitude  latitude  \
# 0          attack  Not fleeing        False   -123.122    47.247
# 1          attack  Not fleeing        False   -122.892    45.487
# 2           other  Not fleeing        False    -97.281    37.695
# 3          attack  Not fleeing        False   -122.422    37.763
# 4          attack  Not fleeing        False   -104.692    40.384
# ...           ...          ...          ...        ...       ...
# 5711       attack         Foot        False   -119.821    36.758
# 5712        other  Not fleeing        False   -112.298    40.531
# 5713       attack  Not fleeing        False    -87.856    42.899
# 5714        other          NaN        False    -73.010    40.875
# 5715       attack        Other        False    -79.677    34.609
#
#       is_geocoding_exact
# 0                   True
# 1                   True
# 2                   True
# 3                   True
# 4                   True
# ...                  ...
# 5711                True
# 5712                True
# 5713                True
# 5714                True
# 5715                True
#
# [5716 rows x 17 columns]

# %% [markdown]
# # Build and test your method chain(s)

# %%
import pandas as pd
import numpy as np

df = (pd.read_csv('fatal-police-shootings-data.csv')
           .drop(['latitude', 'longitude', 'is_geocoding_exact', 'manner_of_death', 'flee'], axis=1)
           .rename(columns={'race': 'ethnicity'})
           .assign(armed= lambda x: np.where(x['armed']=='unarmed', False, True))
           .assign(threat_level= lambda x: np.where(x['threat_level']=='attack', True, None))
           .assign(Armed_Attack= lambda x: np.where(x['armed']== x['threat_level'], True, False))
           .reset_index(drop=True))
df
# Out:
#         id                     name        date  armed   age gender ethnicity  \
# 0        3               Tim Elliot  2015-01-02   True  53.0      M         A
# 1        4         Lewis Lee Lembke  2015-01-02   True  47.0      M         W
# 2        5       John Paul Quintero  2015-01-03  False  23.0      M         H
# 3        8          Matthew Hoffman  2015-01-04   True  32.0      M         W
# 4        9        Michael Rodriguez  2015-01-04   True  39.0      M         H
# ...    ...                      ...         ...    ...   ...    ...       ...
# 5711  6245           Gregory Putnik  2020-10-18   True  32.0      M         W
# 5712  6247  Tutuila Pine Koonwaiyou  2020-10-18   True  37.0      M       NaN
# 5713  6242                      NaN  2020-10-19   True  43.0      M       NaN
# 5714  6243           Paul Sulkowski  2020-10-19   True  46.0      M       NaN
# 5715  6244                      NaN  2020-10-19   True   NaN      M       NaN
#
#                  city state  signs_of_mental_illness threat_level  \
# 0             Shelton    WA                     True         True
# 1               Aloha    OR                    False         True
# 2             Wichita    KS                    False         None
# 3       San Francisco    CA                     True         True
# 4               Evans    CO                    False         True
# ...               ...   ...                      ...          ...
# 5711           Fresno    CA                    False         True
# 5712           Tooele    UT                    False         None
# 5713  South Milwaukee    WI                    False         True
# 5714            Coram    NY                    False         None
# 5715       Emmitsburg    MD                    False         True
#
#       body_camera  Armed_Attack
# 0           False          True
# 1           False          True
# 2           False         False
# 3           False          True
# 4           False          True
# ...           ...           ...
# 5711        False          True
# 5712        False         False
# 5713        False          True
# 5714        False         False
# 5715        False          True
#
# [5716 rows x 13 columns]

# %% [markdown]
# # Wrap your method chain(s) in a function

# %%
##Step 2: Wrap your method chain(s) in a function
import pandas as pd
import numpy as np


def load_and_process(url_or_path_to_csv_file):
    

    # Method Chain 1 (Load data and deal with missing data)

    df1 = (
        pd.read_csv('url_or_path_to_csv_file')
        .drop(['latitude', 'longitude', 'is_geocoding_exact', 'manner_of_death', 'flee'], axis=1)
        .rename(columns={'race': 'ethnicity'})
             
             
    # Method Chain 2 (Create new columns, drop others, and do processing)

    df2 = (df1
           .assign(armed= lambda x: np.where(x['armed']=='unarmed', False, True))
           .assign(threat_level= lambda x: np.where(x['threat_level']=='attack', True, None))
           .assign(Armed_Attack= lambda x: np.where(x['armed']== x['threat_level'], True, False))
           .reset_index(drop=True)
          )
 

return df2

# %%
from Scripts import project_functions 
df = project_functions.load_and_process('fatal-police-shootings-data.csv')
df
# Out:
#                          name        date  armed   age gender ethnicity  \
# 0                  Tim Elliot  2015-01-02   True  53.0      M         A
# 1            Lewis Lee Lembke  2015-01-02   True  47.0      M         W
# 2          John Paul Quintero  2015-01-03  False  23.0      M         H
# 3             Matthew Hoffman  2015-01-04   True  32.0      M         W
# 4           Michael Rodriguez  2015-01-04   True  39.0      M         H
# ...                       ...         ...    ...   ...    ...       ...
# 5711           Gregory Putnik  2020-10-18   True  32.0      M         W
# 5712  Tutuila Pine Koonwaiyou  2020-10-18   True  37.0      M       NaN
# 5713                      NaN  2020-10-19   True  43.0      M       NaN
# 5714           Paul Sulkowski  2020-10-19   True  46.0      M       NaN
# 5715                      NaN  2020-10-19   True   NaN      M       NaN
#
#                  city state  signs_of_mental_illness threat_level  \
# 0             Shelton    WA                     True         True
# 1               Aloha    OR                    False         True
# 2             Wichita    KS                    False         None
# 3       San Francisco    CA                     True         True
# 4               Evans    CO                    False         True
# ...               ...   ...                      ...          ...
# 5711           Fresno    CA                    False         True
# 5712           Tooele    UT                    False         None
# 5713  South Milwaukee    WI                    False         True
# 5714            Coram    NY                    False         None
# 5715       Emmitsburg    MD                    False         True
#
#       body_camera  Armed_Attack
# 0           False          True
# 1           False          True
# 2           False         False
# 3           False          True
# 4           False          True
# ...           ...           ...
# 5711        False          True
# 5712        False         False
# 5713        False          True
# 5714        False         False
# 5715        False          True
#
# [5716 rows x 12 columns]

# %% [markdown]
# # Task 4: Conduct an Exploratory Data Analysis (EDA) on your dataset.¶

# %% [markdown]
# #### Observation 1:
#
# * The mean age is surprisingly high. The youngest victim of fatal police shootings was only six

# %%
from Scripts import project_functions 
df = project_functions.load_and_process('fatal-police-shootings-data.csv')
df.describe()
# Out:
#                age
# count  5456.000000
# mean     37.139113
# std      13.068117
# min       6.000000
# 25%      27.000000
# 50%      35.000000
# 75%      46.000000
# max      91.000000

# %% [markdown]
# #### Observation 2:
#
# * Although people from white ehtnic backgrounds are the most frequent victims, Hispanic and African American ethnicities are high. This becomes particularly alarming considering the population proportion of white ethnicities to either Hispanic or African American ethnicities

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from Scripts import project_functions 
df = project_functions.load_and_process('fatal-police-shootings-data.csv')

sns.set_theme(style="ticks", font_scale=1.3,)
plt.rc("axes.spines", top=False, right=False)

cov = sns.countplot(y='ethnicity', data=df)
plt.title('Number of Fatalities by Ethnicity')
cov.set(xlabel='Count of Fatal Police Shootings', ylabel='ethnicity')
plt.show()

# %% [markdown]
# #### Observation 3:
# * The number of police shootings seems fairly constant throught the past 5 years. There are notable differences in 2020 most probably due to the corona virus pandemic.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from Scripts import project_functions 
df = project_functions.load_and_process('fatal-police-shootings-data.csv')

df['Date'] = pd.to_datetime(df['date'])
df.Date.dt.date

sns.set_theme(style="ticks", font_scale=1,)
cov = sns.displot(data = df, x="Date", hue="ethnicity", multiple="dodge")
plt.title('Number of Police Shooting Fatalities Per Year')
cov.set(xlabel= 'Years of Cases', ylabel='Fatal Police Shooting')
plt.show()

# %% [markdown]
# #### Observation 3:
# * The distribution of fatal shootings is high in texas and florida. It is important to note that canada is included in the data and as such our society must be cautious of this alarming development.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from Scripts import project_functions 
df = project_functions.load_and_process('fatal-police-shootings-data.csv')

fig, cov=plt.subplots(figsize=(9,15))
sns.set_theme(style="ticks", font_scale=1.,)
plt.rc("axes.spines", top=False, right=False)

cov = sns.countplot(y='state', data=df)
plt.title('Number of Fatalities by State')
cov.set(xlabel='Count of Fatal Police Shootings', ylabel='state')
plt.show()
